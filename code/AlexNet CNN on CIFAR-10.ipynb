# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
class unpickle:
    def __init__(self,path):
        self.path = path
    def extraction(self):
        with open(self.path, 'rb') as fo:
            dict = pickle.load(fo, encoding='bytes')
        return dict
    
up = unpickle('/Klaptor/Python/Deep Learning/Datasets/CIFAR-10/cifar-10-batches-py/data_batch_1')

data = up.extraction()

# %%
for k in data:
    print(k)
# Out:
# b'batch_label'
# b'labels'
# b'data'
# b'filenames'

# %%
def extraction(path):
    with open(path, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
abc = extraction('/Klaptor/Python/Deep Learning/Datasets/CIFAR-10/cifar-10-batches-py/data_batch_1'); abc
# Out:
# {b'batch_label': b'training batch 1 of 5',
#  b'labels': [6,
#   9,
#   9,
#   4,
#   1,
#   1,
#   2,
#   7,
#   8,
#   3,
#   4,
#   7,
#   7,
#   2,
#   9,
#   9,
#   9,
#   3,
#   2,
#   6,
#   4,
#   3,
#   6,
#   6,
#   2,
#   6,
#   3,
#   5,
#   4,
#   0,
#   0,
#   9,
#   1,
#   3,
#   4,
#   0,
#   3,
#   7,
#   3,
#   3,
#   5,
#   2,
#   2,
#   7,
#   1,
#   1,
#   1,
#   2,
#   2,
#   0,
#   9,
#   5,
#   7,
#   9,
#   2,
#   2,
#   5,
#   2,
#   4,
#   3,
#   1,
#   1,
#   8,
#   2,
#   1,
#   1,
#   4,
#   9,
#   7,
#   8,
#   5,
#   9,
#   6,
#   7,
#   3,
#   1,
#   9,
#   0,
#   3,
#   1,
#   3,
#   5,
#   4,
#   5,
#   7,
#   7,
#   4,
#   7,
#   9,
#   4,
#   2,
#   3,
#   8,
#   0,
#   1,
#   6,
#   1,
#   1,
#   4,
#   1,
#   8,
#   3,
#   9,
#   6,
#   6,
#   1,
#   8,
#   5,
#   2,
#   9,
#   9,
#   8,
#   1,
#   7,
#   7,
#   0,
#   0,
#   6,
#   9,
#   1,
#   2,
#   2,
#   9,
#   2,
#   6,
#   6,
#   1,
#   9,
#   5,
#   0,
#   4,
#   7,
#   6,
#   7,
# ...

# %%
batch_1 = unpickle('/Klaptor/Python/Deep Learning/Datasets/CIFAR-10/cifar-10-batches-py/data_batch_1')

# %%
batch_1

# %%
for k in batch_1:
    print(k)
# Out:
# b'batch_label'
# b'labels'
# b'data'
# b'filenames'

# %%
narray = batch_1[b'data']

# %%
narray
# Out:
# array([[ 59,  43,  50, ..., 140,  84,  72],
#        [154, 126, 105, ..., 139, 142, 144],
#        [255, 253, 253, ...,  83,  83,  84],
#        ...,
#        [ 71,  60,  74, ...,  68,  69,  68],
#        [250, 254, 211, ..., 215, 255, 254],
#        [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8)

# %%
len(narray)
# Out:
# 10000

# %%
first = narray[0]

# %%
len(first)
# Out:
# 3072

# %%
first_reshaped = first.reshape(3,32,32).transpose([1, 2, 0])

# %%
np.shape(first_reshaped)
# Out:
# (32, 32, 3)

# %%
plt.imshow(first_reshaped)

# %%
transformed_array = []
for i in narray:
    transformed_array.append(i.reshape(3,32,32).transpose([1, 2, 0]))
print(transformed_array[0])
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]

# %%
plt.imshow(transformed_array[1])
